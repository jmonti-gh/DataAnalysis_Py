# %% [markdown]
# # Pandas
# - Solve short hands-on challenges to perfect your data manipulation skills.
# - https://www.kaggle.com/learn/pandas

# %% [markdown]
# ## 6.- Exercise: Renaming and Combining
# - Data comes in from many sources. Help it all make sense together.
# - Columns names, index names, or other naming conventions to change.
# - Combine data from multiple Dataframes and/or Series.

# %%
import pandas as pd

print('pd.__version__:', pd.__version__)

# pd.set_option('display.max_rows', 5)
# Out:
# pd.__version__: 1.5.3

# %%
reviews = pd.read_csv('Red.csv')
reviews.head(2)
# Out:
#            Name Country   Region                 Winery  Rating  \
# 0  Pomerol 2011  France  Pomerol  Château La Providence     4.2
# 1    Lirac 2017  France    Lirac     Château Mont-Redon     4.3
#
#    NumberOfRatings  Price  Year
# 0              100   95.0  2011
# 1              100   15.5  2017

# %%
## Add a twitter_region column !
reviews['twitter_region'] = '@' +  reviews.Region
reviews.head()
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year twitter_region
# 0  Château La Providence     4.2              100  95.00  2011       @Pomerol
# 1     Château Mont-Redon     4.3              100  15.50  2017         @Lirac
# 2             Renzo Masi     3.9              100   7.45  2015       @Toscana
# 3             Cavalchina     3.5              100   8.72  2019     @Bardolino
# 4            Markowitsch     3.9              100  29.15  2016     @Carnuntum

# %%
# ## Add rows with NaN values - Not in this case...
# display(reviews.head(2))
# print(len(reviews))

# ndf_row1 = pd.DataFrame({'Name': 'Name1', 'Country': np.nan, 'Region': 'Reg1',
#                          'Winery': 'Win1', 'Rating': 1, 'NumberOfRatings': 101,
#                          'Price': 10.1, 'Year': 2021, 'twitter_region': '@Reg1'}, index=[0])
# revs = pd.concat([reviews, ndf_row1]).reset_index(drop=True)    # concat at the end
# ndf_row2 = pd.DataFrame({'Name': 'Name2', 'Country': np.nan, 'Region': 'Reg2',
#                          'Winery': 'Win2', 'Rating': 2, 'NumberOfRatings': 202,
#                          'Price': 20., 'Year': 2022, 'twitter_region': '@Reg2'}, index=[0])
# revs = pd.concat([ndf_row2, revs]).reset_index(drop=True)    # concat at the beginning and in the same df

# lst_row3 = ['Name3', np.nan, 'Reg3', 'Win3', np.nan, 303, np.nan,2023, '@Reg3']
# revs.loc[3423.5] = lst_row3                         # make index float and insert in .5
# print('revs.index.dtype now:', revs.index.dtype)
# revs = revs.sort_index().reset_index(drop=True)     # return index to int and add
# revs

# %% [markdown]
# #### 1.- region_1 and region_2 are pretty uninformative names for locale columns in the dataset. Create a copy of reviews with these columns renamed to region and locale, respectively.

# %%
# Ragion x district and Winery wine_cellar
renamed = reviews.rename(columns={'Region': 'district', 'Winery': 'wine_cellar'})
renamed.head()
# Out:
#                                  Name  Country   district  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#              wine_cellar  Rating  NumberOfRatings  Price  Year twitter_region
# 0  Château La Providence     4.2              100  95.00  2011       @Pomerol
# 1     Château Mont-Redon     4.3              100  15.50  2017         @Lirac
# 2             Renzo Masi     3.9              100   7.45  2015       @Toscana
# 3             Cavalchina     3.5              100   8.72  2019     @Bardolino
# 4            Markowitsch     3.9              100  29.15  2016     @Carnuntum

# %% [markdown]
# #### 2.- Set the index name in the dataset to wines.

# %%
# reindexed = reviews.rename_axis('wines', axis='rows')
reindexed = reviews.rename_axis('wines', axis='rows').rename_axis('Cols_name', axis='columns')
reindexed.head()
# Out:
# Cols_name                                Name  Country     Region  \
# wines
# 0                                Pomerol 2011   France    Pomerol
# 1                                  Lirac 2017   France      Lirac
# 2          Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                              Bardolino 2019    Italy  Bardolino
# 4              Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
# Cols_name                 Winery  Rating  NumberOfRatings  Price  Year  \
# wines
# 0          Château La Providence     4.2              100  95.00  2011
# 1             Château Mont-Redon     4.3              100  15.50  2017
# 2                     Renzo Masi     3.9              100   7.45  2015
# 3                     Cavalchina     3.5              100   8.72  2019
# 4                    Markowitsch     3.9              100  29.15  2016
#
# Cols_name twitter_region
# wines
# 0               @Pomerol
# 1                 @Lirac
# 2               @Toscana
# ...

# %% [markdown]
# #### 3.- The Things on Reddit dataset includes product links from a selection of top-ranked forums ("subreddits") on reddit.com. Run the cell below to load a dataframe of products mentioned on the /r/gaming subreddit and another dataframe for products mentioned on the r//movies subreddit.

# %%
# Create two new df from original loaded 
# Make two news df based on two country of origen.
rev_nz = reviews.loc[reviews.Country == 'New Zealand']
display(rev_nz.head(2))
rev_bz = reviews.loc[reviews.Country == 'Brazil']
display(rev_bz.head(2))
# Out:
#                                  Name      Country       Region  \
# 6   Marion's Vineyard Pinot Noir 2016  New Zealand    Wairarapa
# 78                    Pinot Noir 2016  New Zealand  Marlborough
#
#                  Winery  Rating  NumberOfRatings  Price  Year twitter_region
# 6              Schubert     4.0              100  43.87  2016     @Wairarapa
# 78  Clos Henri Vineyard     3.9              102  27.78  2016   @Marlborough
#                   Name Country        Region          Winery  Rating  \
# 23  Virtus Tannat 2013  Brazil  Serra Gaúcha  Monte Paschoal     2.9
# 66  Fausto Tannat 2015  Brazil  Serra Gaúcha         Pizzato     3.6
#
#     NumberOfRatings  Price  Year twitter_region
# 23              100   6.77  2013  @Serra Gaúcha
# 66             1012  11.35  2015  @Serra Gaúcha

# %%
# Create a DataFrame of products mentioned on either subreddit. (wines reviewed on either df)
combined_wines = pd.concat([rev_bz, rev_nz])
display(combined_wines.head(2), combined_wines.tail(2))
# Out:
#                   Name Country        Region          Winery  Rating  \
# 23  Virtus Tannat 2013  Brazil  Serra Gaúcha  Monte Paschoal     2.9
# 66  Fausto Tannat 2015  Brazil  Serra Gaúcha         Pizzato     3.6
#
#     NumberOfRatings  Price  Year twitter_region
# 23              100   6.77  2013  @Serra Gaúcha
# 66             1012  11.35  2015  @Serra Gaúcha
#                                               Name      Country       Region  \
# 8622                       Reserve Pinot Noir 2017  New Zealand  Marlborough
# 8644  Private Bin Merlot - Cabernet Sauvignon 2016  New Zealand  Hawke's Bay
#
#            Winery  Rating  NumberOfRatings  Price  Year twitter_region
# 8622  Villa Maria     3.8               98  25.79  2017   @Marlborough
# 8644  Villa Maria     3.4               99  12.60  2016   @Hawke's Bay

# %% [markdown]
# #### 4.- The Powerlifting Database dataset on Kaggle includes one CSV table for powerlifting meets and a separate one for powerlifting competitors. Run the cell below to load these datasets into dataframes:

# %%
# NumberOfRatings common values to join
left = rev_bz.set_index(['NumberOfRatings'])
right = rev_nz.set_index(['NumberOfRatings'])

left.join(right, lsuffix='_B', rsuffix='_N')
# Out:
#                                                    Name_B Country_B  \
# NumberOfRatings
# 31                           Family Vineyards Tannat 2015    Brazil
# 31                           Family Vineyards Tannat 2015    Brazil
# 62                           Family Vineyards Merlot 2015    Brazil
# 80                                     Seival Tannat 2012    Brazil
# 85                                    Reserva Merlot 2016    Brazil
# 90                                    Intenso Tannat 2013    Brazil
# 95                        Reserva Cabernet Sauvignon 2012    Brazil
# 100                                    Virtus Tannat 2013    Brazil
# 103                                   Merlot Reserva 2008    Brazil
# 117                       Reserva Cabernet Sauvignon 2013    Brazil
# 128                                  Dedicato Tannat 2013    Brazil
# 146                                   Reserva Tannat 2014    Brazil
# ...

# %%
### correct one:
# powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))

## remember more exercises with:
''' .join(), .merge(), .pivot()'''
