# %% [markdown]
# # Pandas
# - Solve short hands-on challenges to perfect your data manipulation skills.
# - https://www.kaggle.com/learn/pandas

# %% [markdown]
# ## Creating, Reading and Writing
# - You can't work with data if you can't read it. Get started here.

# %%
import pandas as pd

pd.__version__
# Out:
# '1.5.3'

# %% [markdown]
# ### Creating Data

# %% [markdown]
# #### DataFrames
# A DataFrame is a table. It contains an array of individual entries, each of which has a certain value. Each entry corresponds to a row (or record) and a column.

# %%
# DataFrame (dict-list) constructor
df = pd.DataFrame({'Yes': [50, 21], 'No': [131, 2]})
df
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
df_str = pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 'Sue': ['Pretty good.', 'Bland.']})
df_str
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
# Non-default Index with index parameter in the constructor
pd.DataFrame({'Bob': ['I liked it.', 'It was awful.'], 
              'Sue': ['Pretty good.', 'Bland.']},
             index=['Product A', 'Product B'])
# Out:
#                      Bob           Sue
# Product A    I liked it.  Pretty good.
# Product B  It was awful.        Bland.

# %% [markdown]
# #### Series
# A Series, by contrast, is a sequence of data values. If a DataFrame is a table, a Series is a list. And in fact you can create one with nothing more than a list:

# %%
s = pd.Series([1, 2, 3, 4, 5])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
# Series with row names using index parm, and an overall Series name
s1 = pd.Series([30, 35, 40],
               index=['2015 Sales', '2016 Sales', '2017 Sales'],
               name='Product A')

s1
# Out:
# 2015 Sales    30
# 2016 Sales    35
# 2017 Sales    40
# Name: Product A, dtype: int64

# %% [markdown]
# ### Reading data files

# %%
redwine_df = pd.read_csv('Red.csv')
redwine_df
# Out:
#                                     Name        Country  \
# 0                           Pomerol 2011         France
# 1                             Lirac 2017         France
# 2     Erta e China Rosso di Toscana 2015          Italy
# 3                         Bardolino 2019          Italy
# 4         Ried Scheibner Pinot Noir 2016        Austria
# ...                                  ...            ...
# 8661                6th Sense Syrah 2016  United States
# 8662     Botrosecco Maremma Toscana 2016          Italy
# 8663                     Haut-Médoc 2010         France
# 8664                         Shiraz 2019      Australia
# 8665    Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 0                     Pomerol      Château La Providence     4.2
# 1                       Lirac         Château Mont-Redon     4.3
# 2                     Toscana                 Renzo Masi     3.9
# 3                   Bardolino                 Cavalchina     3.5
# 4                   Carnuntum                Markowitsch     3.9
# ...                       ...                        ...     ...
# 8661                     Lodi       Michael David Winery     3.8
# 8662          Maremma Toscana                Le Mortelle     4.0
# 8663               Haut-Médoc  Château Cambon La Pelouse     3.7
# 8664  South Eastern Australia                Yellow Tail     3.5
# 8665                  Tunuyán                  Salentein     3.4
#
#       NumberOfRatings  Price  Year
# 0                 100  95.00  2011
# 1                 100  15.50  2017
# 2                 100   7.45  2015
# 3                 100   8.72  2019
# 4                 100  29.15  2016
# ...               ...    ...   ...
# 8661              994  16.47  2016
# 8662              995  20.09  2016
# 8663              996  23.95  2010
# 8664              998   6.21  2019
# 8665              999   7.88  2016
#
# [8666 rows x 8 columns]

# %%
redwine_df.shape
# Out:
# (8666, 8)

# %%
# function to return a multiline string with a simple 2x3 table of values of large tables
# I will use this function to present df rows, cols & entries values.

def mk_table(rows, cols):
    line = '-' * (1 + 9 * 3 + 13) + '\n'
    titln = f"| {'rows':^9} | {'columns':^9} | {'entries':^13} |\n"
    valsln = f"| {rows:>9,} | {cols:>9} | {(rows * cols):>13,} |\n"
    return line + titln + line + valsln + line

print(mk_table(129971, 14))     # winmag-data-130k-v2.csv dataset case
# Out:
# -----------------------------------------
# |   rows    |  columns  |    entries    |
# -----------------------------------------
# |   129,971 |        14 |     1,819,594 |
# -----------------------------------------

# %%
print(mk_table(redwine_df.shape[0], redwine_df.shape[1]))
# Out:
# -----------------------------------------
# |   rows    |  columns  |    entries    |
# -----------------------------------------
# |     8,666 |         8 |        69,328 |
# -----------------------------------------

# %%
display(redwine_df.head())
display(redwine_df.tail())
# Out:
#                                  Name  Country     Region  \
# 0                        Pomerol 2011   France    Pomerol
# 1                          Lirac 2017   France      Lirac
# 2  Erta e China Rosso di Toscana 2015    Italy    Toscana
# 3                      Bardolino 2019    Italy  Bardolino
# 4      Ried Scheibner Pinot Noir 2016  Austria  Carnuntum
#
#                   Winery  Rating  NumberOfRatings  Price  Year
# 0  Château La Providence     4.2              100  95.00  2011
# 1     Château Mont-Redon     4.3              100  15.50  2017
# 2             Renzo Masi     3.9              100   7.45  2015
# 3             Cavalchina     3.5              100   8.72  2019
# 4            Markowitsch     3.9              100  29.15  2016
#                                   Name        Country  \
# 8661              6th Sense Syrah 2016  United States
# 8662   Botrosecco Maremma Toscana 2016          Italy
# 8663                   Haut-Médoc 2010         France
# 8664                       Shiraz 2019      Australia
# 8665  Portillo Cabernet Sauvignon 2016      Argentina
#
#                        Region                     Winery  Rating  \
# 8661                     Lodi       Michael David Winery     3.8
# 8662          Maremma Toscana                Le Mortelle     4.0
# 8663               Haut-Médoc  Château Cambon La Pelouse     3.7
# 8664  South Eastern Australia                Yellow Tail     3.5
# 8665                  Tunuyán                  Salentein     3.4
#
#       NumberOfRatings  Price  Year
# 8661              994  16.47  2016
# 8662              995  20.09  2016
# 8663              996  23.95  2010
# 8664              998   6.21  2019
# 8665              999   7.88  2016

# %%
redwine_df1 = pd.read_csv('Red.csv', index_col=0)
redwine_df1
# Out:
#                                           Country                   Region  \
# Name
# Pomerol 2011                               France                  Pomerol
# Lirac 2017                                 France                    Lirac
# Erta e China Rosso di Toscana 2015          Italy                  Toscana
# Bardolino 2019                              Italy                Bardolino
# Ried Scheibner Pinot Noir 2016            Austria                Carnuntum
# ...                                           ...                      ...
# 6th Sense Syrah 2016                United States                     Lodi
# Botrosecco Maremma Toscana 2016             Italy          Maremma Toscana
# Haut-Médoc 2010                            France               Haut-Médoc
# Shiraz 2019                             Australia  South Eastern Australia
# Portillo Cabernet Sauvignon 2016        Argentina                  Tunuyán
#
#                                                        Winery  Rating  \
# Name
# Pomerol 2011                            Château La Providence     4.2
# Lirac 2017                                 Château Mont-Redon     4.3
# Erta e China Rosso di Toscana 2015                 Renzo Masi     3.9
# Bardolino 2019                                     Cavalchina     3.5
# Ried Scheibner Pinot Noir 2016                    Markowitsch     3.9
# ...                                                       ...     ...
# 6th Sense Syrah 2016                     Michael David Winery     3.8
# Botrosecco Maremma Toscana 2016                   Le Mortelle     4.0
# Haut-Médoc 2010                     Château Cambon La Pelouse     3.7
# Shiraz 2019                                       Yellow Tail     3.5
# Portillo Cabernet Sauvignon 2016                    Salentein     3.4
#
#                                     NumberOfRatings  Price  Year
# Name
# Pomerol 2011                                    100  95.00  2011
# Lirac 2017                                      100  15.50  2017
# Erta e China Rosso di Toscana 2015              100   7.45  2015
# Bardolino 2019                                  100   8.72  2019
# Ried Scheibner Pinot Noir 2016                  100  29.15  2016
# ...                                             ...    ...   ...
# 6th Sense Syrah 2016                            994  16.47  2016
# Botrosecco Maremma Toscana 2016                 995  20.09  2016
# Haut-Médoc 2010                                 996  23.95  2010
# Shiraz 2019                                     998   6.21  2019
# Portillo Cabernet Sauvignon 2016                999   7.88  2016
#
# [8666 rows x 7 columns]

# %%
print(mk_table(redwine_df1.shape[0], redwine_df1.shape[1]))
# Out:
# -----------------------------------------
# |   rows    |  columns  |    entries    |
# -----------------------------------------
# |     8,666 |         7 |        60,662 |
# -----------------------------------------
