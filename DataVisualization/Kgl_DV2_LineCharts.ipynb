# %% [markdown]
# # Kaggle Data Visualization
# - Make great data visualizations. A great way to see the power of coding!

# %% [markdown]
# ## 2. Line Charts
# - Visualize trends over time

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
'Setup Complete'
# Out:
# 'Setup Complete'

# %% [markdown]
# ### Selecting the dataset

# %%
import zipfile as zfm

with zfm.ZipFile('DataToVisualize.zip') as zf:
    numln = 1
    for ln in zf.open('spotify.csv'):
        print(ln)
        if numln == 15: break
        numln += 1
# Out:
# b'Date,Shape of You,Despacito,Something Just Like This,HUMBLE.,Unforgettable\n'
# b'2017-01-06,12287078,,,,\n'
# b'2017-01-07,13190270,,,,\n'
# b'2017-01-08,13099919,,,,\n'
# b'2017-01-09,14506351,,,,\n'
# b'2017-01-10,14275628,,,,\n'
# b'2017-01-11,14372699,,,,\n'
# b'2017-01-12,14148108,,,,\n'
# b'2017-01-13,14536236,275178.0,,,\n'
# b'2017-01-14,14173311,1144886.0,,,\n'
# b'2017-01-15,12889849,1288198.0,,,\n'
# b'2017-01-16,14128468,1827581.0,,,\n'
# b'2017-01-17,14158281,2177449.0,,,\n'
# b'2017-01-18,14293365,2528408.0,,,\n'
# b'2017-01-19,14252159,2893300.0,,,\n'

# %% [markdown]
# ### Load & Esamine the Data

# %%
with zfm.ZipFile('DataToVisualize.zip') as zf:
    df = pd.read_csv(zf.open('spotify.csv'), index_col='Date', parse_dates=True)
df
# Out:
#             Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN        NaN
# 2017-01-07      13190270        NaN                       NaN        NaN
# 2017-01-08      13099919        NaN                       NaN        NaN
# 2017-01-09      14506351        NaN                       NaN        NaN
# 2017-01-10      14275628        NaN                       NaN        NaN
# ...                  ...        ...                       ...        ...
# 2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# ...

# %% [markdown]
# ### Plot the data

# %%
fig, axe = plt.subplots(figsize=(16,6))
sns.lineplot(data=df, ax=axe)
axe.set_title('Daily Global Streams of Popular Songs in 2017-2018')
# Out:
# Text(0.5, 1.0, 'Spotify streaming times')

# %% [markdown]
# ### Plot a subset of data

# %%
df.columns, type(df.columns)
# Out:
# (Index(['Shape of You', 'Despacito', 'Something Just Like This', 'HUMBLE.',
#         'Unforgettable'],
#        dtype='object'),
#  pandas.core.indexes.base.Index)

# %%
cols = list(df.columns)
cols, type(cols)
# Out:
# (['Shape of You',
#   'Despacito',
#   'Something Just Like This',
#   'HUMBLE.',
#   'Unforgettable'],
#  list)

# %%
### plot the lines corresponding to the first two columns
fig, ax1 = plt.subplots(figsize=(16,6))
sns.lineplot(data=df['Shape of You'], label='Shape of you', ax=ax1)
sns.lineplot(data=df['Despacito'], label='Despacito', ax=ax1)
#ax1.set_xlabel('Date')
ax1.set_xlabel(df.index.name)
ax1.set_title('Daily Global Streams of "Shape of You" and "Despacito" in 2017-2018')
# Out:
# Text(0.5, 1.0, 'Daily Global Streams of "Shape of You" and "Despacito" in 2017-2018')

# %%
df[['Shape of You', 'Despacito']]
# Out:
#             Shape of You  Despacito
# Date
# 2017-01-06      12287078        NaN
# 2017-01-07      13190270        NaN
# 2017-01-08      13099919        NaN
# 2017-01-09      14506351        NaN
# 2017-01-10      14275628        NaN
# ...                  ...        ...
# 2018-01-05       4492978  3450315.0
# 2018-01-06       4416476  3394284.0
# 2018-01-07       4009104  3020789.0
# 2018-01-08       4135505  2755266.0
# 2018-01-09       4168506  2791601.0
#
# [366 rows x 2 columns]

# %%
### Using matplotlib.pyplot
fig, axm = plt.subplots(figsize=(16,6))
axm.plot(df.index, df[['Shape of You', 'Despacito']])

# %%
fig, axm = plt.subplots(figsize=(16,6))
axm.plot(df.index, df['Shape of You'], label='Shape of You')
axm.plot(df.index, df['Despacito'], label='Despacito')
axm.legend()
axm.set_title('Daily Global Streams of Popular Songs in 2017-2018')
# Out:
# Text(0.5, 1.0, 'Daily Global Streams of Popular Songs in 2017-2018')

# %%
df[['Shape of You', 'Despacito']]
# Out:
#             Shape of You  Despacito
# Date
# 2017-01-06      12287078        NaN
# 2017-01-07      13190270        NaN
# 2017-01-08      13099919        NaN
# 2017-01-09      14506351        NaN
# 2017-01-10      14275628        NaN
# ...                  ...        ...
# 2018-01-05       4492978  3450315.0
# 2018-01-06       4416476  3394284.0
# 2018-01-07       4009104  3020789.0
# 2018-01-08       4135505  2755266.0
# 2018-01-09       4168506  2791601.0
#
# [366 rows x 2 columns]

# %%
df.loc[:, ['Shape of You', 'Despacito']]
# Out:
#             Shape of You  Despacito
# Date
# 2017-01-06      12287078        NaN
# 2017-01-07      13190270        NaN
# 2017-01-08      13099919        NaN
# 2017-01-09      14506351        NaN
# 2017-01-10      14275628        NaN
# ...                  ...        ...
# 2018-01-05       4492978  3450315.0
# 2018-01-06       4416476  3394284.0
# 2018-01-07       4009104  3020789.0
# 2018-01-08       4135505  2755266.0
# 2018-01-09       4168506  2791601.0
#
# [366 rows x 2 columns]

# %%
df.iloc[:, 0]
# Out:
# Date
# 2017-01-06    12287078
# 2017-01-07    13190270
# 2017-01-08    13099919
# 2017-01-09    14506351
# 2017-01-10    14275628
#                 ...
# 2018-01-05     4492978
# 2018-01-06     4416476
# 2018-01-07     4009104
# 2018-01-08     4135505
# 2018-01-09     4168506
# Name: Shape of You, Length: 366, dtype: int64

# %%
df.iloc[:, [0, 1]]
# Out:
#             Shape of You  Despacito
# Date
# 2017-01-06      12287078        NaN
# 2017-01-07      13190270        NaN
# 2017-01-08      13099919        NaN
# 2017-01-09      14506351        NaN
# 2017-01-10      14275628        NaN
# ...                  ...        ...
# 2018-01-05       4492978  3450315.0
# 2018-01-06       4416476  3394284.0
# 2018-01-07       4009104  3020789.0
# 2018-01-08       4135505  2755266.0
# 2018-01-09       4168506  2791601.0
#
# [366 rows x 2 columns]

# %%
df[{'Shape of You', 'Despacito'}]
# Out:
# C:\Users\jm\AppData\Local\Temp\ipykernel_14760\2670318215.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   df[{'Shape of You', 'Despacito'}]
#             Despacito  Shape of You
# Date
# 2017-01-06        NaN      12287078
# 2017-01-07        NaN      13190270
# 2017-01-08        NaN      13099919
# 2017-01-09        NaN      14506351
# 2017-01-10        NaN      14275628
# ...               ...           ...
# 2018-01-05  3450315.0       4492978
# 2018-01-06  3394284.0       4416476
# 2018-01-07  3020789.0       4009104
# 2018-01-08  2755266.0       4135505
# 2018-01-09  2791601.0       4168506
#
# [366 rows x 2 columns]
