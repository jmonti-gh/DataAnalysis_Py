# %% [markdown]
# raw cell?

# %% [markdown]
# ### It seems raw cell don't exist in vscode JN

# %% [markdown]
# >Exports the notebooks to PDF, HTML, from vscode ¿?
#
# JN , vi , vim.. mode base editors.
# shortcuts, it seems similar to vi (i tried a, dd - b new cell below).
# command mode & edit mode (two mode editor, like vi again).
# escape & return to change modes.
# m & y to change cells type.
# ctrl + return run code not care which mode you are in (don't mode the curse), shift + return same but mode the cursor to the next cell.
# dd to delete a cell an z to undo (ctrl+z also works in vscode).
# cut & paste cells: x & v (similar again to win ctrl+ - not vi in this case). copy is c.
# ..
# ..

# %%
# py code
for i in range(8, -7, -2):
    print(i, end=' ')
# Out:
# 8 6 4 2 0 -2 -4 -6

# %% [markdown]
# ## New MKD
# . one
# . two

# %% [markdown]
# ### Importing and Exporting Data
# Another video lesson about JN/labs

# %%
trin = 'Add Some Code only to put a Color Note'
if 'only to' in trin:
    print(trin)
# Out:
# Add Some Code only to put a Color Note

# %% [markdown]
# ### Other code that is in the turorial (try the necesary imports & JN magic-commands)

# %%
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
x = np.linspace(0, 100, 500)
y = np.cumsum(np.random.randn(500, 6), 0)

# %%
plt.figure(figsize=(10,5))
plt.plot(x, y)
plt.legend('ABCDEF', ncol=2, loc='upper left')

# %% [markdown]
# ### Importing Data, get from a public API.
# Similar the one in dr. Chuck curse but use requests module... ¿?

# %%
# Later probe this...

# %% [markdown]
# ### Dynamic plots with Bokeh
# Also later.
# Bokeh is similar to mathplotlib but permit dinamic view of grafic.
# but to export a job is adecuate de better known mathplotlib library.
# seaborn is another to try...

# %%
# Later... again

# %% [markdown]
# ### Exporting to Excel
